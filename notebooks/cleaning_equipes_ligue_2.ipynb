# %%
import pandas as pd

# %%
equipe_ligue = pd.read_csv('Equipes Ligue 2.csv')
equipe_ligue.head()
# Out:
#       Rank                     teamId  teamImageId  teamFullName       team  \
# 0    TOTAL                        NaN          NaN           NaN          -
# 1  AVERAGE                        NaN          NaN           NaN          -
# 2     Rank                     teamId  teamImageId  teamFullName       Team
# 3        1  15ip1h6m0b4e8xfi597y5uo5u         3288     Dunkerque  Dunkerque
# 4        1  75gwk94q9jkoh78jk8nlay4xj         2298         Laval      Laval
#
#    teamAbbrevName  teamShortName  newestTeamColor                   leagueId  \
# 0             NaN            NaN              NaN                        NaN
# 1             NaN            NaN              NaN                        NaN
# 2  teamAbbrevName  teamShortName  newestTeamColor                   leagueId
# 3             DUN      Dunkerque              NaN  4w7x0s5gfs5abasphlha5de8k
# 4             LAV          Laval          #FFA500  4w7x0s5gfs5abasphlha5de8k
#
# ...

# %%
equipe_ligue.isnull().sum()
# Out:
# Rank                    0
# teamId                  2
# teamImageId             2
# teamFullName            2
# team                    0
# teamAbbrevName          2
# teamShortName           2
# newestTeamColor        34
# leagueId                2
# leagueName              2
# MinIncET                0
# DistanceRun             0
# WalkDist                0
# JogDist                 0
# RunDist                 0
# HiSpeedRunDist          0
# SprintDist              0
# WalkCount               0
# JogCount                0
# RunCount                0
# HiSpeedRunCount         0
# SprintCount             0
# optaTeamId              2
# week                    2
# game                    2
# home                    2
# away                    2
# win                     2
# draw                    2
# loss                    2
# date                    2
# gameId                  2
# opponentId              2
# opponentTeamImageId     2
# oppOptaTeamId           2
# ...

# %%
equipe_ligue.dropna(inplace=True)

# %%
equipe_ligue.isnull().sum()
# Out:
# Rank                   0
# teamId                 0
# teamImageId            0
# teamFullName           0
# team                   0
# teamAbbrevName         0
# teamShortName          0
# newestTeamColor        0
# leagueId               0
# leagueName             0
# MinIncET               0
# DistanceRun            0
# WalkDist               0
# JogDist                0
# RunDist                0
# HiSpeedRunDist         0
# SprintDist             0
# WalkCount              0
# JogCount               0
# RunCount               0
# HiSpeedRunCount        0
# SprintCount            0
# optaTeamId             0
# week                   0
# game                   0
# home                   0
# away                   0
# win                    0
# draw                   0
# loss                   0
# date                   0
# gameId                 0
# opponentId             0
# opponentTeamImageId    0
# oppOptaTeamId          0
# teamFullName.1         0
# opponentFullName       0
# ...

# %%
equipe_ligue.to_csv('equipes_ligue_clean.csv', index=False)

# %%
equipe_national = pd.read_csv('Equipes National1.csv')
equipe_national.head()
# Out:
#       Rank                     teamId  teamImageId       teamFullName  \
# 0    TOTAL                        NaN          NaN                NaN
# 1  AVERAGE                        NaN          NaN                NaN
# 2     Rank                     teamId  teamImageId       teamFullName
# 3        1  67igj3fctu1kt6ntkrwpdt72i          921        Châteauroux
# 4        1  f0ticxo5bjjif0gb54ewfdppm        21581  Paris 13 Atletico
#
#                 team  teamAbbrevName  teamShortName  newestTeamColor  \
# 0                  -             NaN            NaN              NaN
# 1                  -             NaN            NaN              NaN
# 2               Team  teamAbbrevName  teamShortName  newestTeamColor
# 3        Châteauroux             CHA    Châteauroux          #0000FF
# 4  Paris 13 Atletico             P13       Paris 13              NaN
#
#                     leagueId           leagueName  ...  oppOptaTeamId  \
# ...

# %%
equipe_ligue.isnull().sum()
# Out:
# Rank                   0
# teamId                 0
# teamImageId            0
# teamFullName           0
# team                   0
# teamAbbrevName         0
# teamShortName          0
# newestTeamColor        0
# leagueId               0
# leagueName             0
# MinIncET               0
# DistanceRun            0
# WalkDist               0
# JogDist                0
# RunDist                0
# HiSpeedRunDist         0
# SprintDist             0
# WalkCount              0
# JogCount               0
# RunCount               0
# HiSpeedRunCount        0
# SprintCount            0
# optaTeamId             0
# week                   0
# game                   0
# home                   0
# away                   0
# win                    0
# draw                   0
# loss                   0
# date                   0
# gameId                 0
# opponentId             0
# opponentTeamImageId    0
# oppOptaTeamId          0
# teamFullName.1         0
# opponentFullName       0
# ...

# %%
joueurs_ligue = pd.read_csv('Joueurs Ligue 2.csv')
joueurs_ligue.head()
# Out:
#       Rank                   playerId  playerImageId           player  \
# 0    TOTAL                        NaN            NaN              NaN
# 1  AVERAGE                        NaN            NaN              NaN
# 2     Rank                   playerId  playerImageId           Player
# 3        1  3weuuu2vlyod9x7gnk2v9r1ed          80443         V. Sasso
# 4        1  e6d4o93vge4jfpycvj7mdwx5h         242062  Alexandre Mendy
#
#     playerFullName                pos  teamImageId     teamName  \
# 0              NaN                NaN          NaN          NaN
# 1              NaN                NaN          NaN          NaN
# 2   playerFullName                pos  teamImageId     teamName
# 3    Vincent Sasso  Right Centre Back         3288    Dunkerque
# 4  Alexandre Mendy     Centre Forward          147  Montpellier
#
#    teamShortName  teamAbbrevName  ...  opponent  score  finalScoreOpponent  \
# 0            NaN             NaN  ...       NaN    NaN                 NaN
# ...

# %%
joueurs_ligue.isnull().sum()
# Out:
# Rank                      0
# playerId                  2
# playerImageId          1030
# player                    2
# playerFullName            2
# pos                     742
# teamImageId               2
# teamName                  2
# teamShortName             2
# teamAbbrevName            2
# newestTeamId              2
# newestTeam                2
# newestTeamColor         578
# newestLeagueId            2
# newestLeague              2
# optaPersonId              2
# firstName                 2
# lastName                  2
# Position                742
# GM                        0
# Min                       0
# Age                       0
# MinIncET                  0
# DistanceRun               0
# WalkDist                  0
# JogDist                   0
# RunDist                   0
# HiSpeedRunDist            0
# SprintDist                0
# WalkCount                 0
# JogCount                  0
# RunCount                  0
# HiSpeedRunCount           0
# ...

# %%
joueurs_ligue.dropna(inplace=True)

# %%
joueurs_ligue.isnull().sum()
# Out:
# Rank                   0
# playerId               0
# playerImageId          0
# player                 0
# playerFullName         0
# pos                    0
# teamImageId            0
# teamName               0
# teamShortName          0
# teamAbbrevName         0
# newestTeamId           0
# newestTeam             0
# newestTeamColor        0
# newestLeagueId         0
# newestLeague           0
# optaPersonId           0
# firstName              0
# lastName               0
# Position               0
# GM                     0
# Min                    0
# Age                    0
# MinIncET               0
# DistanceRun            0
# WalkDist               0
# JogDist                0
# RunDist                0
# HiSpeedRunDist         0
# SprintDist             0
# WalkCount              0
# JogCount               0
# RunCount               0
# HiSpeedRunCount        0
# SprintCount            0
# week                   0
# game                   0
# home                   0
# ...

# %%
joueurs_ligue.to_csv('joueurs_ligue_clean.csv', index=False)

# %%
joueurs_national = pd.read_csv('Joueurs National 1.csv')
joueurs_national.head()
# Out:
#       Rank                   playerId  playerImageId       player  \
# 0    TOTAL                        NaN            NaN          NaN
# 1  AVERAGE                        NaN            NaN          NaN
# 2     Rank                   playerId  playerImageId       Player
# 3        1  7upcymlpcp1zi8gojnl4krnpx         177277  B. Youssouf
# 4        1  1v77h0qhlk8mxixqpraz77zyt          73847    B. Angoua
#
#         playerFullName                pos  teamImageId        teamName  \
# 0                  NaN                NaN          NaN             NaN
# 1                  NaN                NaN          NaN             NaN
# 2       playerFullName                pos  teamImageId        teamName
# 3  Bendjaloud Youssouf         Right Back          693         Sochaux
# 4      Benjamin Angoua  Right Centre Back         3271  Stade Briochin
#
#     teamShortName  teamAbbrevName  ...  opponent  score  finalScoreOpponent  \
# ...

# %%
joueurs_national.isnull().sum()
# Out:
# Rank                      0
# playerId                  2
# playerImageId          1131
# player                    2
# playerFullName            2
# pos                     230
# teamImageId               2
# teamName                  2
# teamShortName             2
# teamAbbrevName            2
# newestTeamId              2
# newestTeam                2
# newestTeamColor        1986
# newestLeagueId            2
# newestLeague              2
# optaPersonId              2
# firstName                 2
# lastName                  2
# Position                230
# GM                        0
# Min                       0
# Age                       0
# MinIncET                  0
# DistanceRun               0
# WalkDist                  0
# JogDist                   0
# RunDist                   0
# HiSpeedRunDist            0
# SprintDist                0
# WalkCount                 0
# JogCount                  0
# RunCount                  0
# HiSpeedRunCount           0
# ...

# %%
joueurs_national.dropna(inplace=True)

# %%
joueurs_national.isnull().sum()
# Out:
# Rank                   0
# playerId               0
# playerImageId          0
# player                 0
# playerFullName         0
# pos                    0
# teamImageId            0
# teamName               0
# teamShortName          0
# teamAbbrevName         0
# newestTeamId           0
# newestTeam             0
# newestTeamColor        0
# newestLeagueId         0
# newestLeague           0
# optaPersonId           0
# firstName              0
# lastName               0
# Position               0
# GM                     0
# Min                    0
# Age                    0
# MinIncET               0
# DistanceRun            0
# WalkDist               0
# JogDist                0
# RunDist                0
# HiSpeedRunDist         0
# SprintDist             0
# WalkCount              0
# JogCount               0
# RunCount               0
# HiSpeedRunCount        0
# SprintCount            0
# week                   0
# game                   0
# home                   0
# ...

# %%
joueurs_national.to_csv('joueurs_national_clean.csv', index=False)
